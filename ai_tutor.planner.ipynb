# %% [markdown]
# # Unit test writing using a multi-step prompt
#
# Complex tasks, such as writing unit tests, can benefit from multi-step prompts. In contrast to a single prompt, a multi-step prompt generates text from GPT and then feeds that output text back into subsequent prompts. This can help in cases where you want GPT to reason things out before answering, or brainstorm a plan before executing it.
#
# In this notebook, we use a 3-step prompt to write unit tests in Python using the following steps:
#
# 1. **Explain**: Given a Python function, we ask GPT to explain what the function is doing and why.
# 2. **Plan**: We ask GPT to plan a set of unit tests for the function.
#     - If the plan is too short, we ask GPT to elaborate with more ideas for unit tests.
# 3. **Execute**: Finally, we instruct GPT to write unit tests that cover the planned cases.
#
# The code example illustrates a few embellishments on the chained, multi-step prompt:
#
# - Conditional branching (e.g., asking for elaboration only if the first plan is too short)
# - The choice of different models for different steps
# - A check that re-runs the function if the output is unsatisfactory (e.g., if the output code cannot be parsed by Python's `ast` module)
# - Streaming output so that you can start reading the output before it's fully generated (handy for long, multi-step outputs)

# %%
import os
import openai  # used for calling the OpenAI API
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# This is set to `azure`
openai.api_type = "azure"

# The API key for your Azure OpenAI resource.
openai.api_key = os.getenv("OPENAI_API_KEY")

# The base URL for your Azure OpenAI resource. e.g. "https://<your resource name>.openai.azure.com"
openai.api_base = os.getenv("OPENAI_API_BASE")

# Currently Chat Completions API have the following versions available: 2023-03-15-preview
openai.api_version = os.getenv("OPENAI_API_VERSION")

chatgpt_deployment_id = "gpt-4"

color_prefix_by_role = {
    "system": "\033[0m",  # gray
    "user": "\033[0m",  # gray
    "assistant": "\033[92m",  # green
}


def print_messages(messages, color_prefix_by_role=color_prefix_by_role) -> None:
    """Prints messages sent to or from GPT."""
    for message in messages:
        role = message["role"]
        color_prefix = color_prefix_by_role[role]
        content = message["content"]
        print(f"{color_prefix}\n[{role}]\n{content}")


def print_message_delta(delta, color_prefix_by_role=color_prefix_by_role) -> None:
    """Prints a chunk of messages streamed back from GPT."""
    if "role" in delta:
        role = delta["role"]
        color_prefix = color_prefix_by_role[role]
        print(f"{color_prefix}\n[{role}]\n", end="")
    elif "content" in delta:
        content = delta["content"]
        print(content, end="")
    else:
        pass

def concat_chunks_in_response(response, print_text: bool = True) -> str:
    result = ""
    for chunk in response:
        delta = chunk["choices"][0]["delta"]
        if print_text:
            print_message_delta(delta)
        if "content" in delta:
            result += delta["content"]
    return result

# %%
def detailed_explanation_of_student_requirements(
    essay_content: str,  # Python function to test, as a string
    student_requirement:str, # student requirements, as a string
    explain_model: str = "gpt-3.5-turbo",
    temperature: float = 0.4,
    print_text: bool = False,  # optionally prints text; helpful for understanding the function & debugging
):
    """Returns a lesson plan for a given student's requirement and essay content, using a 3-step GPT prompt."""

# create a markdown-formatted message that asks GPT to explain the function, formatted as a bullet list
    explain_system_message = {
        "role": "system",
        "content": "You are a world-class Chinese teaching and research teacher with an eagle eye for learning objectives and student's deep-level requirements. You carefully anlysis learning objectives and student's specific requirements with great detail and accuracy. You organize your analysis in markdown-formatted, bulleted lists.",
    }
    explain_user_message = {
        "role": "user",
        "content": f"""Please explain learning objective and student's requirement in the following steps:
- Analyze the essay content.
- Explain the student's info.
- Try to conjecture student's existing knowledge in Chinese subject.
- Try to conjecture student's existing knowledge on given essay content.
- Analyze the student's potential deep-level requirements as much as possible based on previous steps.
- Define learning objectives: based on your above analysis, define clear and achievable learning objectives for this student.

Organize your explanation in English as a markdown-formatted, bulleted list.

# Input Parameters
## Essay Content
{essay_content}

## Student's Info
{student_requirement}
""",
    }
    explain_messages = [explain_system_message, explain_user_message]
    if print_text:
        print_messages(explain_messages)

    explanation_response = openai.ChatCompletion.create(
        engine=chatgpt_deployment_id,
        messages=explain_messages,
        temperature=temperature,
        stream=True,
    )
    explanation = concat_chunks_in_response(explanation_response)
    explain_assistant_message = {"role": "assistant", "content": explanation}
    return [explain_system_message, explain_user_message, explain_assistant_message]

def plan_with_detailed_natural_language(
    explain_system_message: str,
    explain_user_message: str,
    explain_assistant_message: str,
    ai_teacher_abilities: str,
    print_text: bool = True,
    temperature: float = 0.4
):
    plan_system_message = {
        "role": "system",
        "content": "You are a world-class Chinese teaching and research teacher with an eagle eye for learning objectives and student's deep-level requirements. You carefully create lesson plan which considering learning objectives and student's specific requirements with great detail and accuracy. You organize your lesson plan in markdown-formatted, bulleted lists."
    }
    plan_user_message = {
        "role": "user",
        "content": f"""
# High-Qulity Lesson Plan Standards
1. Perfectly meeting learing objectives
2. Perfectly meeting student's learning preference
3. Escaping teaching student's existing knowledge
4. Only using materials that the ai_teacher_abilities contains.
5. Providing diverse activities in each section
6. Providing attractive introduction
7. Splitting essay into sections should follow the logical point of the essay
9. Splitting essay into sections should aim for sections that can be meaningfully covered within a single lesson or class period, allowing for adequate time to explore the content and complete associated activities
10. Expressing content as activity only for introduction, unit-sections and integrative-sections 

# Input Parameters
## ai teacher abilities
{ai_teacher_abilities}

Create an 1-on-1 Lesson Plan step by step, and remember to follow "High-Qulity Lesson Plan Standards":
- Remind yourself with learing objectives, student's learning preference and student's existing knowledge
- Provide an introduction, following "High-Qulity Lesson Plan Standards" 1,2,3,6
- Divide the essay into smaller unit-sections, following "High-Qulity Lesson Plan Standards" 7,9
- Sequence the unit-sections, arrange the unit-sections in a logical order for teaching, follow the original structure of the essay or reorder the unit-sections based on the complexity of language features or thematic progression
- Provide a few integrative-sections to provide activities which cover the whole essay, such as "Summary and Synthesis", "Review and Reflection", "Conclusion" and so on.
- For each unit-section or integrative-section, following "High-Qulity Lesson Plan Standards" 10:
    * Create engaging activities in section, following "High-Qulity Lesson Plan Standards" 1,2,3,4,5
    * For each activity:
        1. Provide learning materials used (and mention material type) in each activity, following "High-Qulity Lesson Plan Standards" 4
""",
    }
    plan_messages = [
        plan_system_message,
        explain_user_message,
        explain_assistant_message,
        plan_user_message,
    ]
    if print_text:
        print_messages([plan_system_message, plan_user_message])
    plan_response = openai.ChatCompletion.create(
        engine=chatgpt_deployment_id,
        messages=plan_messages,
        temperature=temperature,
        stream=True,
    )
    plan = concat_chunks_in_response(plan_response)
    plan_assistant_message = {"role": "assistant", "content": plan}
    return [plan_user_message, plan_assistant_message]

def generate_executable_plan(
    explain_user_message: str,
    explain_assistant_message: str,
    plan_user_message: str,
    plan_assistant_message: str,
    available_materials: str,
    print_text: bool = True,
    temperature: float = 0.1
):
    # create a markdown-formatted prompt that asks GPT to complete a unit test
    execute_system_message = {
        "role": "system",
        "content": "You are a world-class Chinese teacher with an eagle eye for lesson plan. You write careful, accurate lesson plan. When asked to reply only with json, you write all of your code in a single block.",
    }
    execute_user_message = {
        "role": "user",
        "content": f"""
# Output format
## lesson_plan_schema
```
{{
  "$schema": "http://json-schema.org/draft-07/schema#",
  "type": "object",
  "properties": {{
    "sections": {{
      "type": "array",
      "items": {{
        "type": "object",
        "properties": {{
          "section_title": {{
            "type": "string"
          }},
          "activities": {{
            "type": "array",
            "items": {{
              "type": "object",
              "properties": {{
                "description": {{
                  "type": "string"
                }},
                "masterial_type": {{
                  "type": "string",
                  "enum": ["LLM_CHAT", "CONTENT_REPO"]
                }},
                "content": {{
                  "type": "string"
                }},
                "material_ids": {{
                  "type": "array",
                  "items": {{
                    "type": "integer"
                  }}
                }}
              }},
              "required": ["description", "masterial_type"],
              "oneOf": [
                {{
                  "properties": {{
                    "masterial_type": {{
                      "const": "LLM_CHAT"
                    }}
                  }},
                  "required": ["content"]
                }},
                {{
                  "properties": {{
                    "masterial_type": {{
                      "const": "CONTENT_REPO"
                    }}
                  }},
                  "required": ["material_ids"]
                }}
              ]
            }}
          }}
        }},
        "required": ["section_title", "activities"]
      }}
    }}
  }},
  "required": ["sections"]
}}
```

#Rules
1. For steps whose material type is content_repo, then the material_ids should be selected from available_materials
2. For other steps, material_type should be assigned to llm_chat, and should generate detailed chat_goal for this step

# Input Parameters
## available_materials
{available_materials}

Using json, write a lesson plan excuted by AI teacher for the student, following the text plan above. Enrich lesson plan's section with available materials if adapted. Reply only with json, using the {{lesson_plan_schema}}:
""",
    }
    execute_messages = [
        execute_system_message,
        plan_assistant_message,
        execute_user_message
    ]
    if print_text:
        print_messages([execute_system_message, execute_user_message])

    execute_response = openai.ChatCompletion.create(
        engine=chatgpt_deployment_id,
        messages=execute_messages,
        temperature=temperature,
        stream=True,
    )
    execution = concat_chunks_in_response(execute_response)
    return execution

# %%
essay_content = """
### Essay Summary
《小马过河》讲述了一匹年轻的小马在妈妈的要求下去磨坊驮麦子的过程中，遇到了一条河。小马分别听到了牛和松鼠关于河水深浅的不同说法，犹豫不决，最后决定回家请教妈妈。经过妈妈的启发，小马明白了不能只听别人的话，要自己动脑筋，勇敢尝试。最后，小马顺利地过了河，完成了任务。这个故事教育孩子们要学会独立思考和勇敢尝试。

### Essay New words
"驮", "匹", "欣慰", "哗哗", "犹豫", "迈", "淹"
"""

student_requirement = """
### profile
我是一个小学3年级男生。
### requirements
我今天在课堂上学习过了《小马过河这篇文章》，但是我对这篇文章还没有理解，且有些生字也还不太会读写。
### prefered_format
我更喜欢通过游戏和讲故事的方式来学习。
"""

ai_teacher_abilities = """
### LLM Chat
- large language model's ability

### Existing Content For This Essay in Repository
- new word handwriting rating questions
- role play games
- read aloud rating questions
"""

available_materials = f"""* 5 new word handwriting questions, with material_ids=[101,102,103,104,105]
* 5 role play games, wtih material_ids=[201,202,203,204,205]
* 5 read aloud questions, wtih material_ids=[301,302,303,304,305]"""


[explain_system_message, explain_user_message, explain_assistant_message] = detailed_explanation_of_student_requirements(
    essay_content,
    student_requirement,
    print_text=True
)

[plan_user_message, plan_assistant_message] = plan_with_detailed_natural_language(
    explain_system_message, explain_assistant_message, explain_assistant_message, ai_teacher_abilities
)

generate_executable_plan(
    explain_user_message, explain_assistant_message, 
    plan_user_message, plan_assistant_message, 
    available_materials
)
# Out:
# [system]
# You are a world-class Chinese teaching and research teacher with an eagle eye for learning objectives and student's deep-level requirements. You carefully anlysis learning objectives and student's specific requirements with great detail and accuracy. You organize your analysis in markdown-formatted, bulleted lists.
#
# [user]
# Please explain learning objective and student's requirement in the following steps:
# - Analyze the essay content.
# - Explain the student's info.
# - Try to conjecture student's existing knowledge in Chinese subject.
# - Try to conjecture student's existing knowledge on given essay content.
# - Analyze the student's potential deep-level requirements as much as possible based on previous steps.
# - Define learning objectives: based on your above analysis, define clear and achievable learning objectives for this student.
#
# Organize your explanation in English as a markdown-formatted, bulleted list.
#
# # Input Parameters
# ## Essay Content
#
# ### Essay Summary
# 《小马过河》讲述了一匹年轻的小马在妈妈的要求下去磨坊驮麦子的过程中，遇到了一条河。小马分别听到了牛和松鼠关于河水深浅的不同说法，犹豫不决，最后决定回家请教妈妈。经过妈妈的启发，小马明白了不能只听别人的话，要自己动脑筋，勇敢尝试。最后，小马顺利地过了河，完成了任务。这个故事教育孩子们要学会独立思考和勇敢尝试。
#
# ### Essay New words
# "驮", "匹", "欣慰", "哗哗", "犹豫", "迈", "淹"
#
#
# ## Student's Info
#
# ### profile
# 我是一个小学3年级男生。
# ### requirements
# 我今天在课堂上学习过了《小马过河这篇文章》，但是我对这篇文章还没有理解，且有些生字也还不太会读写。
# ### prefered_format
# 我更喜欢通过游戏和讲故事的方式来学习。
#
#
#
# [assistant]
# # Analysis
#
# ## Analyze the essay content
# - The essay is about a young horse that encounters a river while carrying wheat to the mill under its mother's request.
# - The horse hears different opinions about the depth of the river from a cow and a squirrel and is indecisive.
# - The horse decides to go back and ask its mother for advice.
# - The mother teaches the horse to think independently and be brave to try.
# - In the end, the horse successfully crosses the river and completes the task, teaching children the importance of independent thinking and bravery.
#
# ## Explain the student's info
# - The student is a 3rd-grade boy.
# - He has studied the essay "小马过河" in class but still has difficulty understanding it and reading/writing some new words.
# - He prefers learning through games and storytelling.
#
# ## Conjecture student's existing knowledge in Chinese subject
# - Basic reading and writing skills in Chinese.
# - Familiar with common Chinese characters and grammar.
# - Limited vocabulary and may struggle with more complex texts.
#
# ## Conjecture student's existing knowledge on given essay content
# - The student has a general understanding of the story but may not fully comprehend the deeper meaning and moral.
# - Difficulty in recognizing and writing some new words from the essay.
#
# ## Analyze the student's potential deep-level requirements
# - Improve reading comprehension skills.
# - Enhance vocabulary and learn new words from the essay.
# - Understand the moral of the story and its application in real life.
# - Develop independent thinking and bravery through the story's lessons.
# - Engage in interactive learning methods, such as games and storytelling.
#
# ## Define learning objectives
# - Enhance the student's reading comprehension by discussing the story and its moral.
# - Teach the new words from the essay and practice reading and writing them.
# - Encourage the student to think independently and share their thoughts on the story.
# - Use games and storytelling to make the learning process more engaging and enjoyable.
# - Help the student apply the lessons from the story to their own life experiences.
# [system]
# You are a world-class Chinese teaching and research teacher with an eagle eye for learning objectives and student's deep-level requirements. You carefully create lesson plan which considering learning objectives and student's specific requirements with great detail and accuracy. You organize your lesson plan in markdown-formatted, bulleted lists.
#
# [user]
#
# # High-Qulity Lesson Plan Standards
# 1. Perfectly meeting learing objectives
# 2. Perfectly meeting student's learning preference
# 3. Escaping teaching student's existing knowledge
# 4. Only using materials that the ai_teacher_abilities contains.
# 5. Providing diverse activities in each section
# 6. Providing attractive introduction
# 7. Splitting essay into sections should follow the logical point of the essay
# 9. Splitting essay into sections should aim for sections that can be meaningfully covered within a single lesson or class period, allowing for adequate time to explore the content and complete associated activities
# 10. Expressing content as activity only for introduction, unit-sections and integrative-sections
#
# # Input Parameters
# ## ai teacher abilities
#
# ### LLM Chat
# - large language model's ability
#
# ### Existing Content For This Essay in Repository
# - new word handwriting rating questions
# - role play games
# - read aloud rating questions
#
#
# Create an 1-on-1 Lesson Plan step by step, and remember to follow "High-Qulity Lesson Plan Standards":
# - Remind yourself with learing objectives, student's learning preference and student's existing knowledge
# - Provide an introduction, following "High-Qulity Lesson Plan Standards" 1,2,3,6
# - Divide the essay into smaller unit-sections, following "High-Qulity Lesson Plan Standards" 7,9
# - Sequence the unit-sections, arrange the unit-sections in a logical order for teaching, follow the original structure of the essay or reorder the unit-sections based on the complexity of language features or thematic progression
# - Provide a few integrative-sections to provide activities which cover the whole essay, such as "Summary and Synthesis", "Review and Reflection", "Conclusion" and so on.
# - For each unit-section or integrative-section, following "High-Qulity Lesson Plan Standards" 10:
#     * Create engaging activities in section, following "High-Qulity Lesson Plan Standards" 1,2,3,4,5
#     * For each activity:
#         1. Provide learning materials used (and mention material type) in each activity, following "High-Qulity Lesson Plan Standards" 4
#
#
# [assistant]
# # Lesson Plan: 小马过河 (The Little Horse Crosses the River)
#
# ## Introduction
# 1. Begin the lesson by asking the student about their favorite animal and why they like it. This will help engage the student and make the lesson more relatable.
# 2. Introduce the essay "小马过河" and provide a brief summary of the story. Explain that the story teaches important life lessons about independent thinking and bravery.
#
# ## Unit-Section 1: The Horse Encounters the River
# 1. Read aloud the first part of the essay together with the student, where the horse encounters the river while carrying wheat to the mill.
# 2. Activity: Discuss the horse's feelings and thoughts when encountering the river. Encourage the student to think independently and share their thoughts.
# 3. Activity: Teach new words from this section and practice reading and writing them using the new word handwriting rating questions from the repository.
#
# ## Unit-Section 2: The Horse Asks for Advice
# 1. Read aloud the second part of the essay, where the horse asks the cow and the squirrel for advice about the depth of the river.
# 2. Activity: Role play game from the repository. The student will act as the horse, and the teacher will act as the cow and the squirrel. This will help the student understand the different opinions and the horse's confusion.
# 3. Activity: Teach new words from this section and practice reading and writing them using the new word handwriting rating questions from the repository.
#
# ## Unit-Section 3: The Horse Seeks Mother's Guidance
# 1. Read aloud the third part of the essay, where the horse goes back to its mother for advice.
# 2. Activity: Discuss the mother's advice and how it encourages the horse to think independently and be brave.
# 3. Activity: Teach new words from this section and practice reading and writing them using the new word handwriting rating questions from the repository.
#
# ## Unit-Section 4: The Horse Crosses the River
# 1. Read aloud the final part of the essay, where the horse successfully crosses the river and completes its task.
# 2. Activity: Discuss the horse's feelings and thoughts after crossing the river and the importance of independent thinking and bravery.
# 3. Activity: Teach new words from this section and practice reading and writing them using the new word handwriting rating questions from the repository.
#
# ## Integrative-Section: Summary and Synthesis
# 1. Activity: Have the student summarize the story in their own words, focusing on the key events and the moral of the story.
# 2. Activity: LLM Chat. Encourage the student to share their thoughts on the story, its moral, and how they can apply the lessons to their own life.
#
# ## Integrative-Section: Review and Reflection
# 1. Activity: Read aloud rating questions from the repository. Have the student read the entire essay aloud to practice their reading skills and reinforce their understanding of the story.
# 2. Activity: Reflect on the learning objectives and discuss how the student has improved their reading comprehension, vocabulary, and understanding of the story's moral.
#
# ## Conclusion
# 1. Congratulate the student on their progress and encourage them to continue practicing independent thinking and bravery in their daily life.
# 2. Assign the student to write a short paragraph about a situation where they had to think independently and be brave, using the new words they learned from the essay.
# [system]
# You are a world-class Chinese teacher with an eagle eye for lesson plan. You write careful, accurate lesson plan. When asked to reply only with json, you write all of your code in a single block.
#
# [user]
#
# # Output format
# ## lesson_plan_schema
# ```
# {
#   "$schema": "http://json-schema.org/draft-07/schema#",
#   "type": "object",
#   "properties": {
#     "sections": {
#       "type": "array",
#       "items": {
#         "type": "object",
#         "properties": {
#           "section_title": {
#             "type": "string"
#           },
#           "activities": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "description": {
#                   "type": "string"
#                 },
#                 "masterial_type": {
#                   "type": "string",
#                   "enum": ["LLM_CHAT", "CONTENT_REPO"]
#                 },
#                 "content": {
#                   "type": "string"
#                 },
#                 "material_ids": {
#                   "type": "array",
#                   "items": {
#                     "type": "integer"
#                   }
#                 }
#               },
#               "required": ["description", "masterial_type"],
#               "oneOf": [
#                 {
#                   "properties": {
#                     "masterial_type": {
#                       "const": "LLM_CHAT"
#                     }
#                   },
#                   "required": ["content"]
#                 },
#                 {
#                   "properties": {
#                     "masterial_type": {
#                       "const": "CONTENT_REPO"
#                     }
#                   },
#                   "required": ["material_ids"]
#                 }
#               ]
#             }
#           }
#         },
#         "required": ["section_title", "activities"]
#       }
#     }
#   },
#   "required": ["sections"]
# }
# ```
#
# #Rules
# 1. For steps whose material type is content_repo, then the material_ids should be selected from available_materials
# 2. For other steps, material_type should be assigned to llm_chat, and should generate detailed chat_goal for this step
#
# # Input Parameters
# ## available_materials
# * 5 new word handwriting questions, with material_ids=[101,102,103,104,105]
# * 5 role play games, wtih material_ids=[201,202,203,204,205]
# * 5 read aloud questions, wtih material_ids=[301,302,303,304,305]
#
# Using json, write a lesson plan excuted by AI teacher for the student, following the text plan above. Enrich lesson plan's section with available materials if adapted. Reply only with json, using the {lesson_plan_schema}:
#
#
# [assistant]
# {
#   "sections": [
#     {
#       "section_title": "Introduction",
#       "activities": [
#         {
#           "description": "Ask the student about their favorite animal and why they like it.",
#           "masterial_type": "LLM_CHAT",
#           "content": "What is your favorite animal and why do you like it?"
#         },
#         {
#           "description": "Introduce the essay '小马过河' and provide a brief summary of the story.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Today, we will read an essay called '小马过河' (The Little Horse Crosses the River). It is a story about a little horse who learns important life lessons about independent thinking and bravery."
#         }
#       ]
#     },
#     {
#       "section_title": "Unit-Section 1: The Horse Encounters the River",
#       "activities": [
#         {
#           "description": "Read aloud the first part of the essay together with the student.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Let's read the first part of the essay together, where the horse encounters the river while carrying wheat to the mill."
#         },
#         {
#           "description": "Discuss the horse's feelings and thoughts when encountering the river.",
#           "masterial_type": "LLM_CHAT",
#           "content": "How do you think the horse feels when it encounters the river? What thoughts might be going through its mind?"
#         },
#         {
#           "description": "Teach new words from this section and practice reading and writing them.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [101, 102, 103]
#         }
#       ]
#     },
#     {
#       "section_title": "Unit-Section 2: The Horse Asks for Advice",
#       "activities": [
#         {
#           "description": "Read aloud the second part of the essay.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Now, let's read the second part of the essay, where the horse asks the cow and the squirrel for advice about the depth of the river."
#         },
#         {
#           "description": "Role play game.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [201, 202]
#         },
#         {
#           "description": "Teach new words from this section and practice reading and writing them.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [104, 105]
#         }
#       ]
#     },
#     {
#       "section_title": "Unit-Section 3: The Horse Seeks Mother's Guidance",
#       "activities": [
#         {
#           "description": "Read aloud the third part of the essay.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Let's read the third part of the essay, where the horse goes back to its mother for advice."
#         },
#         {
#           "description": "Discuss the mother's advice.",
#           "masterial_type": "LLM_CHAT",
#           "content": "What advice does the mother give to the horse? How does it encourage the horse to think independently and be brave?"
#         },
#         {
#           "description": "Teach new words from this section and practice reading and writing them.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [101, 102, 103]
#         }
#       ]
#     },
#     {
#       "section_title": "Unit-Section 4: The Horse Crosses the River",
#       "activities": [
#         {
#           "description": "Read aloud the final part of the essay.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Finally, let's read the last part of the essay, where the horse successfully crosses the river and completes its task."
#         },
#         {
#           "description": "Discuss the horse's feelings and thoughts after crossing the river.",
#           "masterial_type": "LLM_CHAT",
#           "content": "How do you think the horse feels after crossing the river? What thoughts might be going through its mind?"
#         },
#         {
#           "description": "Teach new words from this section and practice reading and writing them.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [104, 105]
#         }
#       ]
#     },
#     {
#       "section_title": "Integrative-Section: Summary and Synthesis",
#       "activities": [
#         {
#           "description": "Have the student summarize the story in their own words.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Can you summarize the story in your own words, focusing on the key events and the moral of the story?"
#         },
#         {
#           "description": "Encourage the student to share their thoughts on the story.",
#           "masterial_type": "LLM_CHAT",
#           "content": "What are your thoughts on the story and its moral? How can you apply the lessons to your own life?"
#         }
#       ]
#     },
#     {
#       "section_title": "Integrative-Section: Review and Reflection",
#       "activities": [
#         {
#           "description": "Read aloud rating questions.",
#           "masterial_type": "CONTENT_REPO",
#           "material_ids": [301, 302, 303]
#         },
#         {
#           "description": "Reflect on the learning objectives.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Let's reflect on the learning objectives and discuss how you have improved your reading comprehension, vocabulary, and understanding of the story's moral."
#         }
#       ]
#     },
#     {
#       "section_title": "Conclusion",
#       "activities": [
#         {
#           "description": "Congratulate the student on their progress.",
#           "masterial_type": "LLM_CHAT",
#           "content": "Congratulations on your progress! Remember to continue practicing independent thinking and bravery in your daily life."
#         },
#         {
#           "description": "Assign the student to write a short paragraph.",
#           "masterial_type": "LLM_CHAT",
#           "content": "For your assignment, please write a short paragraph about a situation where you had to think independently and be brave, using the new words you learned from the essay."
#         }
#       ]
#     }
#   ]
# }
# '{\n  "sections": [\n    {\n      "section_title": "Introduction",\n      "activities": [\n        {\n          "description": "Ask the student about their favorite animal and why they like it.",\n          "masterial_type": "LLM_CHAT",\n          "content": "What is your favorite animal and why do you like it?"\n        },\n        {\n          "description": "Introduce the essay \'小马过河\' and provide a brief summary of the story.",\n          "masterial_type": "LLM_CHAT",\n          "content": "Today, we will read an essay called \'小马过河\' (The Little Horse Crosses the River). It is a story about a little horse who learns important life lessons about independent thinking and bravery."\n        }\n      ]\n    },\n    {\n      "section_title": "Unit-Section 1: The Horse Encounters the River",\n      "activities": [\n        {\n          "description": "Read aloud the first part of the essay together with the student.",\n          "masterial_type": "LLM_CHAT",\n          "content": "Let\'s read the first part of the essay together, where the horse encounters the river while carrying wheat to the mill."\n        },\n        {\n          "description": "Discuss the horse\'s feelings and thoughts when encountering the river.",\n          "masterial_type": "LLM_CHAT",\n          "content": "How do you think the horse feels when it encounters the river? What thoughts might be going through its mind?"\n        },\n        {\n          "description": "Teach new words from this section and practice reading and writing them.",\n          "masterial_type": "CONTENT_REPO",\n          "material_ids": [101, 102, 103]\n        }\n      ]\n    },\n    {\n      "section_title": "Unit-Section 2: The Horse Asks for Advice",\n      "activities": [\n        {\n          "description": "Read aloud the second part of the essay.",\n          "masterial_type": "LLM_CHAT",\n          "content": "Now, let\'s read the second part of the essay, where the horse asks the cow and the squirrel for advice about the depth of the river."\n        },\n        {\n          "description": "Role play game.",\n          "masterial_type": "CONTENT_REPO",\n          "material_ids": [201, 202]\n        },\n        {\n          "description": "Teach new words from this section and practice reading and writing them.",\n          "masterial_type": "CONTENT_REPO",\n          "material_ids": [104, 105]\n        }\n      ]\n    },\n    {\n      "section_title": "Unit-Section 3: The Horse Seeks Mother\'s Guidance",\n      "activities": [\n        {\n          "description": "Read aloud the third part of the essay.",\n          "masterial_type": "LLM_CHAT",\n          "content": "Let\'s read the third part of the essay, where the horse goes back to its mother for advice."\n        },\n        {\n          "description": "Discuss the mother\'s advice.",\n          "masterial_type": "LLM_CHAT",\n          "content": "What advice does the mother give to the horse? How does it encourage the horse to think independently and be brave?"\n        },\n        {\n          "description": "Teach new words from this section and practice reading and writing them.",\n          "masterial_type": "CONTENT_REPO",\n          "material_ids": [101, 102, 103]\n        }\n      ]\n    },\n    {\n      "section_title": "Unit-Section 4: The Horse Crosses the River",\n      "activities": [\n        {\n          "description": "Read aloud the final part of the essay.",\n          "masterial_type": "LLM_CHAT",\n          "content": "Finally, let\'s read the last part of the essay, where the horse successfully crosses the river and completes its task."\n        },\n        {\n          "description": "Discuss the horse\'s feelings and thoughts after crossing the river.",\n          "masterial_type": "LLM_CHAT",\n          "content": "How do you think the horse feels after crossing the river? What thoughts might be going through its mind?"\n        },\n        {\n          "description": "Teach new words fr ...

# %% [markdown]
# Make sure to check any code before using it, as GPT makes plenty of mistakes (especially on character-based tasks like this one). For best results, use the most powerful model (GPT-4, as of May 2023).
